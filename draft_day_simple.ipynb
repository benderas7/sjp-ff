# %%
from draft_day_src import pre_draft, draft

# %%
curr_yr, player_pool, owners, keepers, draft_order = pre_draft()

# %%
draft(curr_yr, player_pool, owners, keepers, draft_order, num_rounds=16)
# Out:
# ROUND 1
#
#
# Owen Johnson, you're up!
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     1
#              Round        Player Position Bye  ESPN Projection
# Pick Overall
# 80              11  Adam Thielen       WR  12            151.1
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     5
#              Round           Player Position Bye  ESPN Projection  \
# Pick Overall
# 14               2  Ezekiel Elliott       RB   8            270.2
# 21               3      Josh Gordon       WR  10            130.6
# 39               5    Melvin Gordon       RB  12            168.3
# 68               9      Kareem Hunt       RB   7             75.0
# 80              11     Adam Thielen       WR  12            151.1
# 115             15     Alvin Kamara       RB   9            251.4
# 122             16     James Conner       RB   7            213.6
#
#                       Owner
# Pick Overall
# 14            Andrew Bender
# 21              Max Abdella
# 39             Andrew McGee
# 68             Alex Abdella
# 80             Owen Johnson
# 115            Grant Franke
# 122            Garrett Jung
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     4
# Empty DataFrame
# Columns: [Round, Player, Position, Bye, ESPN Projection, Owner]
# Index: []
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     3
#                     Team Position  Bye  ESPN Projection
# Player
# Saquon Barkley       NYG       RB   11            276.1
# Christian McCaffrey  CAR       RB    7            246.2
# DeAndre Hopkins      HOU       WR   10            193.8
# Davante Adams         GB       WR   11            185.4
# David Johnson        ARI       RB   12            240.3
# Le'Veon Bell         NYJ       RB    4            218.7
# Michael Thomas        NO       WR    9            180.2
# Julio Jones          ATL       WR    9            191.6
# Odell Beckham Jr.    CLE       WR    7            183.0
# Tyreek Hill           KC       WR   12            203.0
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     2
#                 Player  Bye  ESPN Projection
# Position
# QB                 NaN  NaN              NaN
# RB1                NaN  NaN              NaN
# RB2                NaN  NaN              NaN
# WR1       Adam Thielen   12            151.1
# WR2                NaN  NaN              NaN
# FLEX               NaN  NaN              NaN
# TE                 NaN  NaN              NaN
# D/ST               NaN  NaN              NaN
# K                  NaN  NaN              NaN
# Bench1             NaN  NaN              NaN
# Bench2             NaN  NaN              NaN
# Bench3             NaN  NaN              NaN
# Bench4             NaN  NaN              NaN
# Bench5             NaN  NaN              NaN
# Bench6             NaN  NaN              NaN
# Bench7             NaN  NaN              NaN
# You can either enter who you would like to draft or perform
#     any of the following options by entering it's corresponding number:
#
#     1) Look at who you already have drafted
#     2) View your current depth chart
#     3) See Mike Clay's best players available
#     4) See the last 10 players drafted
#     5) Look at the full draft history
#
#     1
#              Round        Player Position Bye  ESPN Projection
# Pick Overall
# 80              11  Adam Thielen       WR  12            151.1
